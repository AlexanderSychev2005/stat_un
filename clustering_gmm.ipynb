# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderSychev2005/stat_un/blob/main/clustering_gmm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

# %%
X, y_true = make_blobs(n_samples=300, centers=3, cluster_std=0.60, random_state=0)

# %%
gmm = GaussianMixture(n_components=3, covariance_type='full', random_state=0)
gmm.fit(X)
# Out:
# GaussianMixture(n_components=3, random_state=0)

# %%
probs = gmm.predict_proba(X)

# %%
labels = gmm.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], c='red', s=100, marker='X', label='Centers')
plt.title('GMM clustering')
plt.legend()
plt.show()
